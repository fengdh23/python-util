# %% [markdown]
# # series

# %%
import pandas as pd
# series 的创建
s = pd.Series([10,7,3,4,5,6])
print(s)

s2 = pd.Series([10,7,3,4,5,6],index=['a','b','c','d','e','f'],name= '月份')
print(s2)
# Out:
# 0    10
# 1     7
# 2     3
# 3     4
# 4     5
# 5     6
# dtype: int64
# a    10
# b     7
# c     3
# d     4
# e     5
# f     6
# Name: 月份, dtype: int64

# %%
# 通过字典 的创建
s = pd.Series({'a':1,'b':2,'c':3})
print(s)

s1 = pd.Series(s,index=['a','c'])
print(s1)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# c    3
# dtype: int64
